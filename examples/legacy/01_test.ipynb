# %% [markdown]
# (example_01)=
# # 01 Example: Hello Tutorials
#
# This is a test. Do equations work here? {math}`\hat{H} = \sum_{ij}K_{ij}\hat{c}^\dagger_{i}\hat{c}_{j} + \sum_{ijkl}V_{ijkl} \hat{c}^\dagger_{i}\hat{c}^\dagger_{j}\hat{c}_{k}\hat{c}_{l}`

# %%
import afqmctools
print(afqmctools.__path__)
